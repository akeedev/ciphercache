# %% [markdown]
# # Say Hello CLI Demo
#
# This notebook demonstrates the simple hello CLI feature from `spec/100-sayhello.md`.

# %%
# %load_ext autoreload
# %autoreload 2

from helloworld import greeting
from helloworld import main as hello_main

# %%
full_name = greeting.get_full_name()
full_name
# Out:
# 'Andreas'

# %%
greeting.greeting_for_user(full_name)
# Out:
# 'Hello, Andreas!'

# %%
hello_main.main()
# Out:
# Hello, Andreas!
